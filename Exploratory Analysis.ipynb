# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/Users/user/Documents/Salary.csv")
df.shape
# Out:
# (487, 17)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary', 'Hourly'],
#       dtype='object')

# %%
#remove duplicates, 88 observations left
df=df.drop_duplicates(subset=('Job Title', 'Company Name','Salary'))
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             8                                     Data Scientist
# 1             9  Avail - Staff Data Scientist (Remote Home Base...
# 2            10                         Data Scientist Contract-W2
# 3            13                                     Data Scientist
# 4            14                        Data Science/Data Scientist
# ..          ...                                                ...
# 446          17                                     Data Scientist
# 447          19  Data Scientist - Operations Research (CPLEX/Gu...
# 449          44  Senior Data Scientist - Deep Learning/Computer...
# 450          56                              Data Science Engineer
# 452         106  Principal Applied Scientist (Machine Learning)...
#
#          Salary Estimate                                    Job Description  \
# 0    $165,000 /yr (est.)  Data Scientist ($160-170 yr) Must have profess...
# ...

# %%
df.Salary.hist()
df['Salary'].mean()
# Out:
# 101987.45454545454

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot('Salary')
# Out:
# <AxesSubplot:>

# %%
pd.pivot_table(df, index='Rating', values = 'Salary').sort_values('Salary',ascending=False)
# Out:
#                Salary
# Rating
#  3.7    198225.000000
#  5.0    152500.000000
#  4.3    147500.000000
#  4.2    145000.000000
#  3.9    120379.333333
#  3.6    118018.000000
#  4.8    112500.000000
#  4.9    110000.000000
#  2.0    102500.000000
#  3.8    102485.454545
#  3.3    100000.000000
#  3.5     96870.000000
#  4.4     93792.857143
#  4.7     93750.000000
# -1.0     93545.620690
#  4.6     87280.000000
#  3.4     86777.500000
#  4.1     77795.000000
#  4.0     38655.000000
#  4.5     15310.000000
